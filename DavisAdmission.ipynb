# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import re

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
# import Housing.csv
df = pd.read_csv('Dataset/Davis.csv')
df
# Out:
#       Campus Measure Name       GPA  Results
# 0      Davis      App GPA  3.490000        0
# 1      Davis      Adm GPA  3.767000        1
# 2      Davis      App GPA  3.894231        0
# 3      Davis      App GPA  3.920909        0
# 4      Davis      App GPA  3.823600        0
# ...      ...          ...       ...      ...
# 47337  Davis      Adm GPA  4.066111        1
# 47338  Davis     Enrl GPA  4.092000        1
# 47339  Davis      App GPA  3.702871        0
# 47340  Davis      Adm GPA  4.094286        1
# 47341  Davis      Adm GPA  3.954412        1
#
# [47342 rows x 4 columns]

# %%
x = df["GPA"]
y = df["Results"]

x=x.to_numpy().reshape(-1,1)
y=y.to_numpy()

# Train Test split 
X_train=x[0:33139]
X_test=x[33139:47342]

Y_train=y[0:33139]
Y_test=y[33139:47342]

#plot scatter plots of train and test data
plt.scatter(X_train,Y_train, color='#e00579')
plt.scatter(X_test,Y_test, color='#71b3ef')

# %%
#train logisitc model
logr = LogisticRegression()
logr.fit(X_train,Y_train)

θ_o=logr.intercept_
θ_1=logr.coef_

#draw logisitc curve using seaborn library
ax=sns.regplot(x="GPA", y="Results",  data=df, logistic=True, ci=None, 
            scatter_kws={'color': 'blue'}, line_kws={'color': '#df355a'})

plt.xlabel('GPA', fontsize=12)
plt.ylabel('Results', fontsize=12)

print(θ_o)
print(θ_1)
# Out:
# [-25.16921615]
# [[6.63849008]]

# %%
#model scores 
train_score=logr.score(X_train, Y_train)
print("train score:", train_score)

test_score=logr.score(X_test, Y_test)
print("test score:",test_score)
# Out:
# train score: 0.7216874377621534
# test score: 0.7285080616771105
